# %% [markdown]
# #

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/rishab260/uta-reallife-drowsiness-dataset/Fold4_part2/Fold4_part2/47/5.mp4
# /kaggle/input/datasets/rishab260/uta-reallife-drowsiness-dataset/Fold4_part2/Fold4_part2/47/10.mp4
# /kaggle/input/datasets/rishab260/uta-reallife-drowsiness-dataset/Fold4_part2/Fold4_part2/47/0.mp4
# /kaggle/input/datasets/rishab260/uta-reallife-drowsiness-dataset/Fold4_part2/Fold4_part2/45/5.mp4
# /kaggle/input/datasets/rishab260/uta-reallife-drowsiness-dataset/Fold4_part2/Fold4_part2/45/10.mp4
# /kaggle/input/datasets/rishab260/uta-reallife-drowsiness-dataset/Fold4_part2/Fold4_part2/45/0.mp4
# /kaggle/input/datasets/rishab260/uta-reallife-drowsiness-dataset/Fold4_part2/Fold4_part2/42/5.mp4
# /kaggle/input/datasets/rishab260/uta-reallife-drowsiness-dataset/Fold4_part2/Fold4_part2/42/10.mp4
# /kaggle/input/datasets/rishab260/uta-reallife-drowsiness-dataset/Fold4_part2/Fold4_part2/42/0.mp4
# ...

# %% [markdown]
# # Added Dataset

# %%
from pathlib import Path

ROOT = Path("/kaggle/input")

print("=" * 100)
print("KAGGLE INPUT DATASETS")
print("=" * 100)

for dataset in sorted(ROOT.iterdir()):
    if not dataset.is_dir():
        continue

    print(f"\n📦 Dataset : {dataset.name}")
    print("-" * 80)

    try:
        items = sorted(dataset.iterdir())

        for item in items:
            prefix = "📁" if item.is_dir() else "📄"
            print(f"{prefix} {item.name}")

    except Exception as e:
        print(e)
# Out:
# ...
# KAGGLE INPUT DATASETS
# ...
#
# 📦 Dataset : datasets
# --------------------------------------------------------------------------------
# 📁 mathiasviborg
# 📁 rishab260

# %% [markdown]
# # Connect to Git

# %%
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()

token = user_secrets.get_secret("GITHUB_TOKEN")

# %%
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()

TOKEN = user_secrets.get_secret("GITHUB_TOKEN")

USERNAME = "kushabarodekar"
REPO = "driver-wellness-ai-v2"

# !git clone https://{USERNAME}:{TOKEN}@github.com/{USERNAME}/{REPO}.git
# Out:
# Cloning into 'driver-wellness-ai-v2'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 67 (delta 25), reused 52 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (67/67), 23.09 KiB | 1.15 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %% [markdown]
# # Pull From Github

# %%
# %cd /kaggle/working/driver-wellness-ai-v2
# !git pull
# !git branch
# Out:
# /kaggle/working/driver-wellness-ai-v2
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 854 bytes | 854.00 KiB/s, done.
# From https://github.com/kushabarodekar/driver-wellness-ai-v2
#    c7a29b5..354b565  main       -> origin/main
# Updating c7a29b5..354b565
# Fast-forward
#  src/datasets/dataset.py | 42 +++++++++++++++++++++++++++++++++++++++---
#  1 file changed, 39 insertions(+), 3 deletions(-)
# * main

# %% [markdown]
# # Subject Split

# %%
# !python -m src.preprocessing.01_subject_split
# Out:
# ...
# UTA-RLDD SUBJECT SPLIT
# ...
# Total Subjects Discovered : 60
#
# Train Subjects      : 42
# Validation Subjects : 9
# Test Subjects       : 9
#
# Saved
# /kaggle/working/driver-wellness-ai-v2/data/metadata/subject_split.csv
# /kaggle/working/driver-wellness-ai-v2/data/metadata/subject_split_summary.csv

# %% [markdown]
# # Genrate Sequence

# %%
# !python -m src.preprocessing.02_sequence_index
# Out:
# ...
# UTA-RLDD SEQUENCE INDEX
# ...
# Saved: /kaggle/working/driver-wellness-ai-v2/data/metadata/sequence_index.csv
# Total sequences: 60345

# %% [markdown]
# # Verify Dataset

# %%
from src.datasets.dataset import DriverWellnessDataset

train_dataset = DriverWellnessDataset("train")

print(train_dataset)

print(len(train_dataset))
# Out:
# train: 46,186 sequences
# ...
# 46186

# %% [markdown]
# # Validate the dataset

# %%
# !python -m src.datasets.dataset
# Out:
# ...
# DATASET VALIDATION
# ...
# train: 46,186 sequences
#
# Train Samples : 46186
#
# Sequence Shape : torch.Size([16, 3, 224, 224])
# Label : tensor(0)
#
# train: 46,186 sequences
# Batch Shape : torch.Size([4, 16, 3, 224, 224])
# Labels Shape : torch.Size([4])
#
# Padded Sequences : 0
#
# Dataset Validation Successful.

# %% [markdown]
# # Validate the model

# %%
# !python -m src.models.model
# Out:
# DriverWellnessModel(
#   (feature_extractor): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
# ...

# %% [markdown]
# # Start training

# %%
# !python -m src.training.train
# Out:
# ...
# Driver Wellness Training
# ...
# Device : cuda
# GPU    : Tesla T4
#
# train: 46,186 sequences
# validation: 7,042 sequences
# /kaggle/working/driver-wellness-ai-v2/src/training/train.py:275: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(
#
# Epoch 1/1
# Training:   0%|                                        | 0/2887 [00:00<?, ?it/s]/kaggle/working/driver-wellness-ai-v2/src/training/train.py:95: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(
# ...
# Training: 100%|██████████████| 2887/2887 [6:52:26<00:00,  8.57s/it, loss=0.0118]
#
# Train Loss : 0.0811
# Validation Loss : 2.8596
# Validation Accuracy : 31.78%
# ----------------------------------------------------------------------
# Epoch                : 1
# Training Loss        : 0.0811
# ...

# %%
from pathlib import Path

checkpoint_dir = Path("outputs/checkpoints")

print("Checkpoint dir exists:", checkpoint_dir.exists())

if checkpoint_dir.exists():
    print(list(checkpoint_dir.glob("*")))
# Out:
# Checkpoint dir exists: True
# [PosixPath('outputs/checkpoints/training_summary.txt'), PosixPath('outputs/checkpoints/confusion_matrix.csv'), PosixPath('outputs/checkpoints/driver_wellness_epoch1.pth')]

# %%
# !zip -r driver-wellness-ai-v2.zip \
    . \
    -x "*.git*" \
    -x "__pycache__/*" \
    -x "*.ipynb_checkpoints*"
# Out:
#   adding: outputs/ (stored 0%)
#   adding: outputs/checkpoints/ (stored 0%)
#   adding: outputs/checkpoints/training_summary.txt (deflated 55%)
#   adding: outputs/checkpoints/confusion_matrix.csv (deflated 3%)
#   adding: outputs/checkpoints/driver_wellness_epoch1.pth (deflated 16%)
#   adding: LICENSE (deflated 41%)
#   adding: data/ (stored 0%)
#   adding: data/processed/ (stored 0%)
#   adding: data/metadata/ (stored 0%)
#   adding: data/metadata/subject_split_summary.csv (stored 0%)
#   adding: data/metadata/subject_split.csv (deflated 69%)
#   adding: data/metadata/sequence_index.csv (deflated 96%)
#   adding: config.py (deflated 70%)
#   adding: src/ (stored 0%)
#   adding: src/utils/ (stored 0%)
#   adding: src/utils/__pycache__/ (stored 0%)
#   adding: src/utils/__pycache__/filesystem.cpython-312.pyc (deflated 41%)
#   adding: src/utils/filesystem.py (deflated 65%)
#   adding: src/models/ (stored 0%)
#   adding: src/models/__init__.py (stored 0%)
# ...

# %%
# !cd /kaggle/working && zip -r driver-wellness-ai-complete.zip driver-wellness-ai-v2
# Out:
#   adding: driver-wellness-ai-v2/ (stored 0%)
#   adding: driver-wellness-ai-v2/outputs/ (stored 0%)
#   adding: driver-wellness-ai-v2/outputs/checkpoints/ (stored 0%)
#   adding: driver-wellness-ai-v2/outputs/checkpoints/training_summary.txt (deflated 55%)
#   adding: driver-wellness-ai-v2/outputs/checkpoints/confusion_matrix.csv (deflated 3%)
#   adding: driver-wellness-ai-v2/outputs/checkpoints/driver_wellness_epoch1.pth (deflated 16%)
#   adding: driver-wellness-ai-v2/outputs/.gitkeep (stored 0%)
#   adding: driver-wellness-ai-v2/.git/ (stored 0%)
#   adding: driver-wellness-ai-v2/.git/FETCH_HEAD (deflated 10%)
#   adding: driver-wellness-ai-v2/.git/branches/ (stored 0%)
#   adding: driver-wellness-ai-v2/.git/config (deflated 29%)
#   adding: driver-wellness-ai-v2/.git/info/ (stored 0%)
#   adding: driver-wellness-ai-v2/.git/info/exclude (deflated 28%)
#   adding: driver-wellness-ai-v2/.git/ORIG_HEAD (stored 0%)
#   adding: driver-wellness-ai-v2/.git/description (deflated 14%)
# ...

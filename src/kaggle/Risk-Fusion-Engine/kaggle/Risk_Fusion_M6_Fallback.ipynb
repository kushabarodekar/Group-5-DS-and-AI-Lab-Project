# %% [markdown]
# # Risk Fusion Engine — M6 Kaggle GPU Fallback
#
# **Purpose:** Stable GPU demo backup when Lightning AI free-tier quotas are exhausted.
#
# 1. **Settings → Accelerator → GPU**
# 2. Run all cells below
# 3. Copy the **public Gradio URL** from the launcher output (`Running on public URL:`)
#
# Same integrated pipeline as `app.py` — no duplicated inference logic.

# %%
# Clone repo (skip if code is already in /kaggle/working or mounted as dataset)
# !git clone https://github.com/YOUR_ORG/Risk-Fusion-Engine-Final.git
# %cd Risk-Fusion-Engine-Final

# %%
# Copy model weights from a Kaggle dataset (adjust path to your dataset slug)
# !ls /kaggle/input/
# !cp -r /kaggle/input/risk-fusion-weights/models/* models/

# %%
# !pip install -q -r requirements.txt

# %%
# !python scripts/check_cuda.py

# %%
# Starts Gradio with share=True — keep this cell running during the demo.
# !python run_kaggle_gradio_fallback.py
